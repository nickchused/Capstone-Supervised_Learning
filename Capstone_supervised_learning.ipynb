# %%
# %matplotlib inline
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import stats

# %%
from google.colab import files
files.upload()

# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# Out:
#      <input type="file" id="files-d730b082-66db-46f6-b1ce-94daf38601da" name="files[]" multiple disabled />
#      <output id="result-d730b082-66db-46f6-b1ce-94daf38601da">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Speed_Dating_Data.csv to Speed_Dating_Data.csv

# %%
dating = pd.read_csv('Speed_Dating_Data.csv', encoding='ISO-8859-1')

# %%
pd.set_option('display.max_columns', None)
dating.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
dating.describe()
# Out:
#                iid           id       gender          idg       condtn  \
# count  8378.000000  8377.000000  8378.000000  8378.000000  8378.000000
# mean    283.675937     8.960248     0.500597    17.327166     1.828837
# std     158.583367     5.491329     0.500029    10.940735     0.376673
# min       1.000000     1.000000     0.000000     1.000000     1.000000
# 25%     154.000000     4.000000     0.000000     8.000000     2.000000
# 50%     281.000000     8.000000     1.000000    16.000000     2.000000
# 75%     407.000000    13.000000     1.000000    26.000000     2.000000
# max     552.000000    22.000000     1.000000    44.000000     2.000000
#
#               wave        round     position     positin1        order  \
# count  8378.000000  8378.000000  8378.000000  6532.000000  8378.000000
# mean     11.350919    16.872046     9.042731     9.295775     8.927668
# std       5.995903     4.358458     5.514939     5.650199     5.477009
# ...

# %%
dating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 12.5+ MB

# %%
pd.set_option('display.max_rows', None)
dating.isnull().sum()

# %%
plt.figure(figsize=(10, 7))
dating.match.value_counts().plot.bar(color=("blue","pink"))
positions = (0, 1)
labels = ('not a match', 'match')
plt.xticks(positions, labels)
plt.tick_params(axis="x", rotation=0, labelsize=18)
plt.tick_params(axis="y", labelsize=18)
plt.title('Match proportion', fontsize = 18)
plt.ylabel('count', fontsize = 18)
plt.show()

# %%
plt.figure(figsize=(10, 7))
dating.dec_o.value_counts().plot.bar(color=("red","green"))
positions = (0, 1)
labels = ('no', 'yes')
plt.xticks(positions, labels)
plt.tick_params(axis="x", rotation=0, labelsize=18)
plt.tick_params(axis="y", labelsize=18)
plt.title('Would you like to see me again?', fontsize = 18)
plt.ylabel('count', fontsize = 18)
plt.show()

# %%
females = dating.loc[dating.gender == 0]

males = dating.loc[dating.gender == 1]

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
females.dec_o.value_counts().plot.bar(color=("red","green"))
positions = (0, 1)
labels = ('no', 'yes')
plt.xticks(positions, labels)
plt.tick_params(axis="x", rotation=0, labelsize=18)
plt.tick_params(axis="y", labelsize=18)
plt.title('Females \n would you like to see me again?', fontsize = 15)
plt.ylabel('count', fontsize = 15)

plt.subplot(1, 2, 2)
males.dec_o.value_counts().plot.bar(color=("red","green"))
positions = (0, 1)
labels = ('no', 'yes')
plt.tick_params(axis="x", rotation=0, labelsize=18)
plt.tick_params(axis="y", labelsize=18)
plt.xticks(positions, labels)
plt.title('Males \n would you like to see me again?', fontsize = 15)
plt.ylabel('count', fontsize = 15)

plt.tight_layout()
plt.show()

# %%
decide_total = dating.groupby(['iid'])['dec_o'].sum()
plt.figure(figsize=(10, 7))
decide_total.value_counts().sort_index().plot.bar(width = 0.75)
plt.tick_params(axis="x", rotation=0)
plt.tick_params(axis="y", labelsize=15)
plt.title('Would you like to see me again?', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.xlabel("number of yes's", fontsize = 15)
plt.show()

# %%
decide_per = round(decide_total/dating.groupby(['iid'])['round'].count(), 1) * 100
plt.figure(figsize=(10, 7))
decide_per.value_counts().sort_index().plot.bar(width = 0.75)
plt.tick_params(axis="x", rotation=0)
plt.tick_params(axis="y", labelsize=15)
plt.title('Percentage of people that wanted to see you again', fontsize = 18)
plt.ylabel('count', fontsize = 18)
plt.xlabel("percentage of yes's", fontsize = 18)
plt.show()

# %%
attractive = dating.groupby(['iid'])['attr_o'].mean()
attractive.head()

# %%
decide_perc = decide_total/dating.groupby(['iid'])['round'].count()
decide_perc.head()

# %%
decide_attr = pd.concat((decide_perc, attractive), axis=1)
decide_attr.head()

# %%
plt.figure(figsize=(10, 7))
plt.scatter(decide_attr[0] * 100, decide_attr['attr_o'])
plt.tick_params(axis="x", rotation=0, labelsize = 15)
plt.tick_params(axis="y", labelsize=15)
plt.title("Percentage of yes's vs attractiveness", fontsize = 15)
plt.xlabel('percentage who said yes', fontsize = 18)
plt.ylabel('Average attractiveness rating', fontsize = 18)
plt.show()

stats.pearsonr(decide_attr[0], decide_attr['attr_o'])
# Out:
# (0.7923267453159207, 6.554950146507875e-120)

# %%
like = dating.groupby(['iid'])['like_o'].mean()
fun = dating.groupby(['iid'])['fun_o'].mean()
shared = dating.groupby(['iid'])['shar_o'].mean()
probability = dating.groupby(['iid'])['prob_o'].mean()
intelligence = dating.groupby(['iid'])['intel_o'].mean()
sincerity = dating.groupby(['iid'])['sinc_o'].mean()
call = dating.groupby(['iid'])['them_cal'].mean()
ambition = dating.groupby(['iid'])['amb_o'].mean()
decide_all = pd.concat((decide_perc, attractive, like, fun, shared, probability, intelligence, sincerity, call, ambition), axis=1)
decide_all.head()

# %%
plt.figure(figsize=(20,15))

plt.subplot(3, 3, 1)
plt.scatter(decide_all[0] * 100, decide_all['like_o'])
plt.title("Percentage of yes's vs how much you were liked")
plt.xlabel('percentage who said yes')
plt.ylabel('Average likeability rating')

plt.subplot(3, 3, 2)
plt.scatter(decide_all[0] * 100, decide_all['attr_o'])
plt.title("Percentage of yes's vs attractiveness")
plt.xlabel('percentage who said yes')
plt.ylabel('Average attractiveness rating')

plt.subplot(3, 3, 3)
plt.scatter(decide_all[0] * 100, decide_all['fun_o'])
plt.title("Percentage of yes's vs how fun people think you are")
plt.xlabel('percentage who said yes')
plt.ylabel('Average fun rating')

plt.subplot(3, 3, 4)
plt.scatter(decide_all[0] * 100, decide_all['shar_o'])
plt.title("Percentage of yes's vs shared interests")
plt.xlabel('percentage who said yes')
plt.ylabel('Average level of shared interests rating')

plt.subplot(3, 3, 5)
plt.scatter(decide_all[0] * 100, decide_all['prob_o'])
plt.title("Percentage of yes's vs perceived probability you will say 'yes' too")
plt.xlabel('percentage who said yes')
plt.ylabel("Your partner's cofidence that you will say 'yes' too")


plt.subplot(3, 3, 6)
plt.scatter(decide_all[0] * 100, decide_all['intel_o'])
plt.title("Percentage of yes's vs intelligence")
plt.xlabel('percentage who said yes')
plt.ylabel('Average intelligence rating')

plt.subplot(3, 3, 7)
plt.scatter(decide_all[0] * 100, decide_all['sinc_o'])
plt.title("Percentage of yes's vs sincerity")
plt.xlabel('percentage who said yes')
plt.ylabel('Average sincerity rating')

plt.subplot(3, 3, 8)
plt.scatter(decide_all[0] * 100, decide_all['them_cal'])
plt.title("Percentage of yes's vs number of people who have contacted you")
plt.xlabel('percentage who said yes')
plt.ylabel('number of people who contacted you 3 to 4 weeks later')

plt.subplot(3, 3, 9)
plt.scatter(decide_all[0] * 100, decide_all['amb_o'])
plt.title("Percentage of yes's vs ambition")
plt.xlabel('percentage who said yes')
plt.ylabel('Average ambition rating')

plt.tight_layout()
plt.show()

# %%
dating.corr().dec_o.sort_values(ascending=False)

# %%
race_count = dating.groupby(['iid'])['race'].sum()/dating.groupby(['iid'])['round'].count()
race_count.head(30)
plt.figure(figsize=(10, 7))
race_count.value_counts().sort_index().plot.barh(width = 0.75).invert_yaxis()
positions = (0, 1, 2 ,3, 4, 5)
labels = ('Declined to answer', 'Black/African American', 'European/Caucasian', 'Latino/Hispanic', 'Asian/Pacific Islander', 'Other')
plt.tick_params(axis="x", rotation=0, labelsize = 15)
plt.tick_params(axis="y", labelsize=15)
plt.yticks(positions, labels)
plt.title('Race partition', fontsize = 15)
plt.xlabel('count', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(10, 7))
dating.samerace.value_counts().plot.bar(color=("orange","blue"))
positions = (0, 1)
labels = ('different race', 'same race')
plt.tick_params(axis="x", rotation=0, labelsize = 15)
plt.tick_params(axis="y", labelsize=15)
plt.xticks(positions, labels)
plt.title('Same or different race', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
dating.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
dating_same = dating[dating.samerace == 1]
dating_different = dating[dating.samerace == 0]

# %%
samerace_per = dating_same['dec_o'].sum()/len(dating_same)
samerace_per
# Out:
# 0.433956574185766

# %%
different_per = dating_different['dec_o'].sum()/len(dating_different)
different_per
# Out:
# 0.4101145792177005

# %%
plt.figure(figsize=(10,5))

plt.subplot(1, 2, 1)
dating_same.dec_o.value_counts().plot.bar(color=("red","green"))
positions = (0, 1)
labels = ('no', 'yes')
plt.title('Same Race', fontsize = 15)
plt.tick_params(axis="x", rotation=0, labelsize=18)
plt.tick_params(axis="y", labelsize=18)
plt.xticks(positions, labels)
plt.xlabel('would you like to see me again?', fontsize = 15)
plt.ylabel('count', fontsize = 15)
print("percentage of yes's for same race dates: {}%".format(round(samerace_per * 100, 2)))

plt.subplot(1, 2, 2)
dating_different.dec_o.value_counts().plot.bar(color=("red","green"))
labels = ('no', 'yes')
plt.tick_params(axis="x", rotation=0, labelsize=18)
plt.tick_params(axis="y", labelsize=18)
plt.xticks(positions, labels)
plt.title("Different race", fontsize = 15)
plt.xlabel('would you like to see me again?', fontsize = 15)
plt.ylabel('count', fontsize = 15)
print("percentage of yes's for different race dates: {}%".format(round(different_per * 100, 2)))

plt.tight_layout()
plt.show()
# Out:
# percentage of yes's for same race dates: 43.4%
# percentage of yes's for different race dates: 41.01%

# %%
import warnings
warnings.filterwarnings('ignore')
age = dating.groupby(['iid'])['age'].mean()
plt.figure(figsize=(10, 7))
plt.hist(age.values)
plt.tick_params(axis="x", labelsize=15)
plt.tick_params(axis="y", labelsize=15)
plt.title('Age distribution', fontsize = 15)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Frequency', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
plt.scatter(dating.groupby(['iid'])['age'].mean(), (decide_total/dating.groupby(['iid'])['round'].count()) * 100)
plt.title('Desirablity vs age', fontsize = 15)
plt.xlabel('age', fontsize = 15)
plt.ylabel("percentage of yes's", fontsize = 15)

plt.tight_layout()
plt.show()

# %%
dating['age_difference'] = dating.age - dating.age_o

decide_age = dating.groupby(['age_difference'])['dec_o'].sum()

plt.figure(figsize=(15,7))

decide_age.plot.bar(width = 0.75)
plt.title("Number of yes's vs age difference", fontsize = 15)
plt.xlabel('age difference', fontsize = 15)
plt.ylabel("number of yes's", fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(15, 7))

dating['age_difference'].value_counts().sort_index().plot.bar(width = 0.75)
plt.title("Distribution of age differences", fontsize = 15)
plt.xlabel('age difference', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.show()

# %%
decide_age_per = dating.groupby(['age_difference'])['dec_o'].sum()/dating['age_difference'].value_counts() * 100

plt.figure(figsize=(15, 7))

decide_age_per.plot.bar(width = 0.75)
plt.title("Percentage of yes's vs age difference", fontsize = 15)
plt.xlabel('age difference', fontsize = 15)
plt.ylabel("percentage of yes's", fontsize = 15)
plt.show()

# %%
dating.corr().dec_o.sort_values(ascending=False).nlargest(12)
# Out:
# dec_o       1.000000
# match       0.522842
# like_o      0.511974
# attr_o      0.487588
# fun_o       0.413475
# shar_o      0.399567
# prob_o      0.308196
# intel_o     0.216238
# sinc_o      0.209030
# them_cal    0.198830
# amb_o       0.183377
# prob        0.151466
# Name: dec_o, dtype: float64

# %%
dating_model = dating[['dec_o', 'like_o', 'attr_o', 'fun_o', 'shar_o', 'prob_o', 'intel_o', 'sinc_o', 'amb_o', 'prob']]
dating_model.dropna(inplace=True)
dating_model.head(10)

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import statsmodels.api as sm

# %%
Y = dating_model['dec_o']
X = dating_model.drop(['dec_o'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

print("The number of observations in training set is {}".format(X_train.shape[0]))
print("The number of observations in test set is {}".format(X_test.shape[0]))
# Out:
# The number of observations in training set is 5447
# The number of observations in test set is 1362

# %%
lr = LogisticRegression(solver='lbfgs',penalty='none', max_iter=1000)

lr.fit(X_train, y_train)

lr_score = lr.score(X_test, y_test)
lr_predictions = lr.predict(X_test)

print('Accuracy of Logistic Regression: {:.3f}'.format(lr_score))
# Out:
# Accuracy of Logistic Regression: 0.772

# %%
from sklearn.model_selection import cross_val_score

lr_clf = LogisticRegression(solver='lbfgs', multi_class='ovr', max_iter=1000)
lr_cv_scores = cross_val_score(lr_clf, X_train, y_train, cv=5)

print('Accuracy scores for the 5 folds: ', lr_cv_scores)
print('Mean cross validation score: {:.3f}'.format(np.mean(lr_cv_scores)))
# Out:
# Accuracy scores for the 5 folds:  [0.76330275 0.77981651 0.77134986 0.77869605 0.75114784]
# Mean cross validation score: 0.769

# %%
knn = KNeighborsClassifier(n_neighbors=10)

knn.fit(X_train, y_train)

knn_score = knn.score(X_test, y_test)
knn_predictions = knn.predict(X_test)

print('Accuracy of KNN (k = 10): {:.3f}'.format(knn_score))
# Out:
# Accuracy of KNN (k = 10): 0.771

# %%
svm = LinearSVC(max_iter=1000)

svm.fit(X_train, y_train)

svm_score = svm.score(X_test, y_test)
svm_predictions = svm.predict(X_test)

print('Accuracy of SVM: {:.3f}'.format(svm_score))
# Out:
# Accuracy of SVM: 0.735

# %%
dt = DecisionTreeClassifier()

dt.fit(X_train,y_train)

dt_score = dt.score(X_test, y_test)
dt_predictions = dt.predict(X_test)

print('Accuracy of Decision Tree: {:.3f} '.format(dt_score))
# Out:
# Accuracy of Decision Tree: 0.690

# %%
rf = RandomForestClassifier(n_estimators = 25)

rf.fit(X_train,y_train)

rf_score = rf.score(X_test, y_test)
rf_predictions = rf.predict(X_test)

print('Accuracy of Random Forest: {:.3f}'.format(rf_score))
# Out:
# Accuracy of Random Forest: 0.763

# %%
rf_clf = RandomForestClassifier(n_estimators=25)
rf_cv_scores = cross_val_score(rf_clf, X_train, y_train, cv=5)

print('Accuracy scores for the 5 folds: ', rf_cv_scores)
print('Mean cross validation score: {:.3f}'.format(np.mean(rf_cv_scores)))
# Out:
# Accuracy scores for the 5 folds:  [0.76422018 0.75688073 0.75573921 0.76033058 0.74931129]
# Mean cross validation score: 0.757

# %%
predictions_dictionary = {'Logistic Regression' : lr_predictions, 'KNN': knn_predictions, 
                          'SVM' : svm_predictions, 'Decision Tree' : dt_predictions, 
                          'Random Forest' : rf_predictions, 'Actual': y_test}

predictions_df = pd.DataFrame(predictions_dictionary)
predictions_df.head(20)

# %%
from sklearn.metrics import confusion_matrix

predictions = lr.predict(X_test)

confusion = confusion_matrix(y_test, predictions, labels=[1, 0])
print(confusion)
# Out:
# [[417 179]
#  [132 634]]

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
  
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
plot_confusion_matrix(cm=confusion, target_names = ['yes', 'no'], title = 'Confusion Matrix \n Would you like to see me again?',normalize=False)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print('Accuracy score: {:.2f}'.format(accuracy))
print('Precision score: {:.2f}'.format(precision))
print('Recall score: {:.2f} \n'.format(recall))
print('Accuracy: The number of correct predictions over the total number of predictions \n')
print('Precision: The proportion of positive predictions that were correct. \n (When the model predicts that our date wants to see us again, they actually do {:.0f}% of the time) \n'.format(accuracy * 100))
print('Rcall: The proportion of positives that were correctly predicted. \n (When our date actually wants to see us again, the model picks it up {:.0f}% of the time)'.format(recall * 100))
# Out:
# Accuracy score: 0.77
# Precision score: 0.76
# Recall score: 0.70
#
# Accuracy: The number of correct predictions over the total number of predictions
#
# Precision: The proportion of positive predictions that were correct.
#  (When the model predicts that our date wants to see us again, they actually do 77% of the time)
#
# Rcall: The proportion of positives that were correctly predicted.
#  (When our date actually wants to see us again, the model picks it up 70% of the time)

# %%
dating.corr().match.sort_values(ascending=False).nlargest(22)

# %%
dating_model_match = dating[['match', 'like_o', 'like', 'fun_o', 'fun', 'shar', 'shar_o', 'attr_o', 'attr', 'prob_o', 'prob', 'intel', 'intel_o', 'sinc', 'sinc_o','amb', 'amb_o', 'prob']]
dating_model_match.dropna(inplace=True)
dating_model_match.head(10)

# %%
Y = dating_model_match['match']
X = dating_model_match.drop(['match'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

print("The number of observations in training set is {}".format(X_train.shape[0]))
print("The number of observations in test set is {}".format(X_test.shape[0]))
# Out:
# The number of observations in training set is 4718
# The number of observations in test set is 1180

# %%
lr = LogisticRegression(solver='lbfgs',penalty='none', max_iter=1000)

lr.fit(X_train, y_train)

lr_score = lr.score(X_test, y_test)
lr_predictions = lr.predict(X_test)

print('Accuracy of Logistic Regression: {:.3f}'.format(lr_score))
# Out:
# Accuracy of Logistic Regression: 0.855

# %%
from sklearn.model_selection import cross_val_score

lr_clf = LogisticRegression(solver='lbfgs', multi_class='ovr', max_iter=1000)
lr_cv_scores = cross_val_score(lr_clf, X_train, y_train, cv=5)

print('Accuracy scores for the 5 folds: ', lr_cv_scores)
print('Mean cross validation score: {:.3f}'.format(np.mean(lr_cv_scores)))
# Out:
# Accuracy scores for the 5 folds:  [0.86016949 0.84639831 0.84322034 0.83244963 0.84093319]
# Mean cross validation score: 0.845

# %%
knn = KNeighborsClassifier(n_neighbors=10)

knn.fit(X_train, y_train)

knn_score = knn.score(X_test, y_test)
knn_predictions = knn.predict(X_test)

print('Accuracy of KNN (k = 10): {:.3f}'.format(knn_score))
# Out:
# Accuracy of KNN (k = 10): 0.855

# %%
svm = LinearSVC(max_iter=1000)

svm.fit(X_train, y_train)

svm_score = svm.score(X_test, y_test)
svm_predictions = svm.predict(X_test)

print('Accuracy of SVM: {:.3f}'.format(svm_score))
# Out:
# Accuracy of SVM: 0.843

# %%
dt = DecisionTreeClassifier()

dt.fit(X_train,y_train)

dt_score = dt.score(X_test, y_test)
dt_predictions = dt.predict(X_test)

print('Accuracy of a Decision Tree: {:.3f} '.format(dt_score))
# Out:
# Accuracy of a Decision Tree: 0.807

# %%
rf = RandomForestClassifier(n_estimators = 25)

rf.fit(X_train,y_train)

rf_score = rf.score(X_test, y_test)
rf_predictions = rf.predict(X_test)

print('Accuracy of Random Forest: {:.3f}'.format(rf_score))
# Out:
# Accuracy of Random Forest: 0.857

# %%
rf_clf = RandomForestClassifier(n_estimators=25)
rf_cv_scores = cross_val_score(rf_clf, X_train, y_train, cv=5)

print('Accuracy scores for the 5 folds: ', rf_cv_scores)
print('Mean cross validation score: {:.3f}'.format(np.mean(rf_cv_scores)))
# Out:
# Accuracy scores for the 5 folds:  [0.85063559 0.85911017 0.83792373 0.84093319 0.84093319]
# Mean cross validation score: 0.846

# %%
from sklearn.metrics import confusion_matrix

predictions = knn.predict(X_test)

confusion = confusion_matrix(y_test, predictions, labels=[1, 0])
print(confusion)
# Out:
# [[ 66 136]
#  [ 35 943]]

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
  
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools
  
    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %%
plot_confusion_matrix(cm=confusion, target_names = ['yes', 'no'], title = 'Confusion Matrix \n Are we a match?',normalize=False)

# %%
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)

print('Accuracy score: {:.2f}'.format(accuracy))
print('Precision score: {:.2f}'.format(precision))
print('Recall score: {:.2f} \n'.format(recall))
print('Accuracy: The number of correct predictions over the total number of predictions \n')
print('Precision: The proportion of positive predictions that were correct. \n (When the model predicts that we are a match, we actually are {:.0f}% of the time) \n'.format(accuracy * 100))
print('Rcall: The proportion of positives that were correctly predicted. \n (When we actually are a match, the model picks it up {:.0f}% of the time)'.format(recall * 100))
# Out:
# Accuracy score: 0.86
# Precision score: 0.65
# Recall score: 0.33
#
# Accuracy: The number of correct predictions over the total number of predictions
#
# Precision: The proportion of positive predictions that were correct.
#  (When the model predicts that we are a match, we actually are 86% of the time)
#
# Rcall: The proportion of positives that were correctly predicted.
#  (When we actually are a match, the model picks it up 33% of the time)

# %%
decision_model = decide_all.drop(['them_cal'], axis=1)
decision_model.head()
# Out:
#        0  attr_o  like_o  fun_o  shar_o  prob_o  intel_o  sinc_o     amb_o
# iid
# 1    0.5     6.7    6.85    7.2     7.1     5.7      8.0     7.4  8.000000
# 2    0.6     7.7    7.60    7.5     6.5     5.5      7.9     7.1  7.500000
# 3    0.5     6.5    6.00    6.2     6.0     4.5      7.3     7.1  7.111111
# 4    0.6     7.0    7.30    7.5     7.2     6.5      7.7     7.1  7.700000
# 5    0.3     5.3    6.10    7.2     6.2     6.5      7.6     7.7  7.800000

# %%
Y = decision_model[0] * 100
X = decision_model.drop([0], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)

print("The number of observations in the training set is {}".format(X_train.shape[0]))
print("The number of observations in the test set is {}".format(X_test.shape[0]))

X_train = sm.add_constant(X_train)

results = sm.OLS(y_train, X_train).fit()

print(results.summary())
# Out:
# The number of observations in the training set is 440
# The number of observations in the test set is 111
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     118.5
# Date:                Mon, 09 Mar 2020   Prob (F-statistic):          8.03e-104
# Time:                        14:31:39   Log-Likelihood:                -1759.4
# No. Observations:                 440   AIC:                             3537.
# Df Residuals:                     431   BIC:                             3574.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from sklearn.metrics import mean_absolute_error
from statsmodels.tools.eval_measures import mse, rmse

X_test = sm.add_constant(X_test)

y_preds = results.predict(X_test)

plt.scatter(y_test, y_preds)
plt.plot(y_test, y_test, color="red")
plt.xlabel("true values", fontsize = 12)
plt.ylabel("predicted values", fontsize = 12)
plt.title("Percentage of dates that want to see you again: true and predicted values")
plt.show()

# %%
print("Mean absolute error of the prediction is: {}".format(mean_absolute_error(y_test, y_preds)))
print("Mean squared error of the prediction is: {}".format(mse(y_test, y_preds)))
print("Root mean squared error of the prediction is: {}".format(rmse(y_test, y_preds)))
print("Mean absolute percentage error of the prediction is: {}".format(np.mean(np.abs((y_test - y_preds) / y_test)) * 100))
# Out:
# Mean absolute error of the prediction is: 10.490960381424433
# Mean squared error of the prediction is: 189.03362736316214
# Root mean squared error of the prediction is: 13.74895004584576
# Mean absolute percentage error of the prediction is: inf
